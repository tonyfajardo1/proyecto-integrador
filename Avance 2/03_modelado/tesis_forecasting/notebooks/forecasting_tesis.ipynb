# %% [markdown]
# # Forecasting (QuickBooks)
#
# Notebook de ejecucion principal del pipeline profundo de pronostico.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / 'src' / 'pipeline.py').exists():
    ROOT = ROOT.parent
if not (ROOT / 'src' / 'pipeline.py').exists():
    raise RuntimeError('No se encontro src/pipeline.py. Abre el notebook dentro de 03_modelado/tesis_forecasting.')
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.pipeline import run_forecasting_thesis

# %%
result = run_forecasting_thesis(alpha=0.95, lead_time=1.0, use_mlflow=False, source='dwh')
benchmark = result['benchmark']
pred = result['predicciones']
drift = result['drift']
winner = result['winner']
winner

# %%
benchmark[['modelo','WAPE_val','WAPE_test','MAE_test','RMSE_test','mejora_vs_baseline_test_wape','gap_wape_train_val','gap_wape_val_test']].head(10)

# %%
drift
