# %% [markdown]
# # 02 - Wrangling
#
# Paso 2: preparar dataset limpio para modelado.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / 'src' / 'wrangling.py').exists():
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.data_source import load_monthly_dataset
from src.wrangling import prepare_for_modeling

# %%
raw = load_monthly_dataset(source='dwh', fallback_quickbooks=True)
wrangled, report = prepare_for_modeling(raw, min_periods_product=4)
display(report)
display(wrangled.head())
# Out:
# F:\proyecto-integrador\Avance 2\03_modelado\forecasting_tesis_v2\src\data_source.py:68: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(
#                          metric  value
# 0                   rows_output  14670
# 1               products_output    904
# 2                periods_output     21
# 3    rows_imputed_missing_month   2434
# 4    products_seasonal_detected     37
# 5  rows_imputed_structural_zero    267
# 6         rows_imputed_temporal   2167
# 7           rows_imputed_median      0
#      periodo                                           producto  \
# 0 2024-07-01  1 CONDIMENSA ACEITES Y GRASAS ACEITE DE GIRASO...
# 1 2024-08-01  1 CONDIMENSA ACEITES Y GRASAS ACEITE DE GIRASO...
# 2 2024-09-01  1 CONDIMENSA ACEITES Y GRASAS ACEITE DE GIRASO...
# ...

# %%
art = ROOT / 'artifacts'
art.mkdir(exist_ok=True)
wrangled.to_csv(art / 'dataset_wrangled.csv', index=False)
report.to_csv(art / 'wrangling_report.csv', index=False)
print('Guardado en', art)
# Out:
# Guardado en F:\proyecto-integrador\Avance 2\03_modelado\forecasting_tesis_v2\artifacts
