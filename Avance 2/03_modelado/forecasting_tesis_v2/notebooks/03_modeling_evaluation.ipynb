# %% [markdown]
# # 03 - Modeling & Evaluation
#
# Benchmark final con controles anti-leakage y regla estacional.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / 'src' / 'modeling.py').exists():
    ROOT = ROOT.parent
if not (ROOT / 'src' / 'modeling.py').exists():
    raise RuntimeError('Abre notebook dentro de 03_modelado/forecasting_tesis_v2')
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.modeling import ModelingConfig, run_full_modeling, save_outputs

# %%
cfg = ModelingConfig(
    source='dwh',
    min_periods_product=4,
    train_frac=0.6,
    val_frac=0.2,
    seasonal_active_months=3,
    seasonal_active_share=0.45,
    cap_quantile=0.995,
)
result = run_full_modeling(cfg)
result['winner']

# %%
result['benchmark']

# %%
result['leakage_report']

# %%
pred = result['predicciones']
pred.head(20)

# %%
art = ROOT / 'artifacts'
save_outputs(result, art)
print('Guardado en', art)
