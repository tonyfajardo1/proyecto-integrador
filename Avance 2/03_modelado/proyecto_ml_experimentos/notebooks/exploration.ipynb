# %% [markdown]
# # Exploracion inicial (fuente PostgreSQL)

# %%
from pathlib import Path
import sys

CWD = Path.cwd().resolve()
candidates = [
    CWD,
    CWD.parent,
    CWD / '03_modelado' / 'proyecto_ml_experimentos',
]
ROOT = next((p for p in candidates if (p / 'src' / 'datasets_postgres.py').exists()), None)
if ROOT is None:
    raise RuntimeError('No se encontro la raiz de proyecto_ml_experimentos (src/datasets_postgres.py).')

if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

for m in ['src', 'src.datasets_postgres']:
    if m in sys.modules:
        del sys.modules[m]

from src.datasets_postgres import load_forecasting_dataset, load_association_dataset, load_anomaly_dataset

# %%
forecast = load_forecasting_dataset()
assoc = load_association_dataset()
anom = load_anomaly_dataset()

print('forecasting:', forecast.shape)
print('association:', assoc.shape)
print('anomaly:', anom.shape)
# Out:
# f:\proyecto-integrador\Avance 2\03_modelado\proyecto_ml_experimentos\src\postgres_loader.py:85: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql_query(query, conn)
# f:\proyecto-integrador\Avance 2\03_modelado\proyecto_ml_experimentos\src\postgres_loader.py:80: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql_query(query, conn)
# forecasting: (12391, 7)
# association: (240046, 3)
# anomaly: (10, 6)

# %%
forecast.head(), assoc.head(), anom.head()
# Out:
# (                                          producto  anio  mes  qty_fabricada  \
#  0  PP SMART SELECTION:SM.SELECTION AJO FUNDA  300G  2025    1         2400.0
#  1  PP SMART SELECTION:SM.SELECTION AJO FUNDA  300G  2025    2          960.0
#  2  PP SMART SELECTION:SM.SELECTION AJO FUNDA  300G  2025    3         1512.0
#  3  PP SMART SELECTION:SM.SELECTION AJO FUNDA  300G  2025    4         1920.0
#  4  PP SMART SELECTION:SM.SELECTION AJO FUNDA  300G  2025    5         1800.0
#
#     qty_planificada  n_ordenes    periodo
#  0           2412.0          3 2025-01-01
#  1            960.0          1 2025-02-01
#  2           1512.0          2 2025-03-01
#  3           1920.0          2 2025-04-01
#  4           1800.0          2 2025-05-01  ,
#    transaccion_id                                producto                fecha
#  0        1410169             * ALINO BOT 310 GRS. (8608)  2026-01-27T00:00:00
#  1        1394902        *ESENCIA VAINILLA 100 ML(8599)CC  2026-01-13T00:00:00
# ...

# %%
anom.describe(include='all')
# Out:
#        agencia  ratio_devolucion  ratio_rentabilidad  ratio_costo  \
# count       10         10.000000           10.000000    10.000000
# unique      10               NaN                 NaN          NaN
# top     ambato               NaN                 NaN          NaN
# freq         1               NaN                 NaN          NaN
# mean       NaN          6.004765           33.379039    66.620961
# std        NaN          1.280323            1.061248     1.061248
# min        NaN          3.176476           31.693364    64.752008
# 25%        NaN          5.602877           32.694437    66.026620
# 50%        NaN          5.923501           33.412793    66.587207
# 75%        NaN          6.663556           33.973380    67.305563
# max        NaN          7.766292           35.247992    68.306636
#
#         ticket_promedio   total_ventas
# count         10.000000      10.000000
# unique              NaN            NaN
# top                 NaN            NaN
# ...
